# %%
from eleanor.source import Source
from eleanor.targetdata import TargetData
import numpy as np
import matplotlib.pyplot as plt
from astropy.coordinates import SkyCoord, Angle
from astropy import units as u
import photutils
from astropy.stats import SigmaClip
from lightkurve.lightcurve import LightCurve as LC

# %%
ra  = Angle(68.959732, u.deg)
dec = Angle(-64.02704, u.deg)
star = Source(coords=SkyCoord(ra, dec), sector=1)
data = TargetData(star, do_pca=False)

# %%
q = data.quality == 0
plt.plot(data.time[q], data.corr_flux[q])
plt.show()

# %%
data.pca()

# %%
plt.figure(figsize=(16,5))
plt.plot(data.time[q], data.pca_flux[q])
plt.show()

# %%
data.save()
# Out:
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-46bbca43e279> in <module>()
# ----> 1 data.save()
#
# ~/Documents/ELLIE/eleanor/targetdata.py in save(self, output_fn, directory)
#     791         ext2 = Table()
#     792         for i in range(len(self.all_apertures)):
# --> 793             ext2[colnames[i]] = self.all_apertures[i]
#     794
#     795         # Creates table for third extention (all raw & corrected fluxes and errors)
#
# NameError: name 'colnames' is not defined
