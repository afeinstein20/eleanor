# %%
import eleanor
import numpy as np
import matplotlib.pyplot as plt

# %%
star = eleanor.Source(tic=38846515, sector=6, tc=True)
# Out:
# Downloading URL https://mast.stsci.edu/tesscut/api/v0.1/astrocut?ra=68.9597092399964&dec=-64.0270368810381&y=31&x=31&units=px&sector=6 to ./tesscut_20190619104540.zip ... [Done]
# Inflating...

# %%
data = eleanor.TargetData(star, height=13, width=13, bkg_size=31, do_psf=False, do_pca=False)

# %%
plt.imshow(data.tpf[0])

# %%
q = data.quality == 0
plt.plot(data.time[q], data.corr_flux[q], '.')

# %%
plt.imshow(data.aperture)

# %%
star.coords[0]

# %%
star.position_on_chip

# %%
plt.imshow(data.tpf[0])

# %%
plt.plot(data.time[q], data.raw_flux[q])

# %%
plt.plot(data.time, data.ffiindex, '.')

# %%
star = eleanor.multi_sectors(tic=307210830, sectors='all', tc=True)
# Out:
# Found star in Sector(s) 2 5 8 9 10
# Downloading URL https://mast.stsci.edu/tesscut/api/v0.1/astrocut?ra=124.531756290083&dec=-68.3129998725044&y=31&x=31&units=px&sector=2 to ./tesscut_20190619104148.zip ... [Done]
# Inflating...
# Downloading URL https://mast.stsci.edu/tesscut/api/v0.1/astrocut?ra=124.531756290083&dec=-68.3129998725044&y=31&x=31&units=px&sector=5 to ./tesscut_20190619104202.zip ... [Done]
# Inflating...
# Downloading URL https://mast.stsci.edu/tesscut/api/v0.1/astrocut?ra=124.531756290083&dec=-68.3129998725044&y=31&x=31&units=px&sector=8 to ./tesscut_20190619104213.zip ... [Done]
# Inflating...
# Downloading URL https://mast.stsci.edu/tesscut/api/v0.1/astrocut?ra=124.531756290083&dec=-68.3129998725044&y=31&x=31&units=px&sector=9 to ./tesscut_20190619104223.zip ... [Done]
# Inflating...
# Downloading URL https://mast.stsci.edu/tesscut/api/v0.1/astrocut?ra=124.531756290083&dec=-68.3129998725044&y=31&x=31&units=px&sector=10 to ./tesscut_20190619104232.zip ... [Done]
# Inflating...

# %%
plt.figure(figsize=(15,5))
for i in range(len(star)):
    print(i)
    data0 = eleanor.TargetData(star[i], height=15, width=15, bkg_size=31, do_psf=False, do_pca=False)

    q0 = data0.quality == 0

    plt.plot(data0.time[q0], data0.corr_flux[q0]/np.median(data0.corr_flux[q0]) + 0.00, 'k.')

plt.ylabel('Normalized Flux', fontsize=24)
plt.xlabel('Time', fontsize=24)
plt.yticks(fontsize=18)
plt.xticks(fontsize=18)

plt.ylim(0.995, 1.002)

plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
star = eleanor.multi_sectors(tic=38846515, sectors='all', tc=True)

plt.figure(figsize=(15,5))

time = np.array([])
flux = np.array([])

#plt.figure(figsize=(15,5))
for i in range(len(star)):
    print(i)
    data0 = eleanor.TargetData(star[i], height=15, width=15, bkg_size=31, do_psf=True, do_pca=False)

    q0 = data0.quality == 0

    plt.plot(data0.time[q0], data0.psf_flux[q0]/np.median(data0.psf_flux[q0]) + 0.00, 'k.')
    
    time = np.append(time, data0.time[q0])
    flux = np.append(flux, data0.psf_flux[q0]/np.median(data0.psf_flux[q0]))

plt.ylabel('Normalized Flux', fontsize=24)
plt.xlabel('Time', fontsize=24)
plt.yticks(fontsize=18)
plt.xticks(fontsize=18)
plt.ylim(0.90, 1.03)

plt.show()
